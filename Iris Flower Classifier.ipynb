# %% [markdown]
# # Iris Flower Classifier

# %% [markdown]
# #### Importing libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn import metrics
from sklearn.metrics import accuracy_score
import pickle

# %% [markdown]
# ## Dataset Description

# %% [markdown]
# <p>A small classic dataset from Fisher, 1936.
# <ul><li>Attribute Type:Real</li>
# <li>Instances:150</li>
# <li>Attributes:4</li>
#
#     This dataset is licensed under a Creative Commons Attribution 4.0 International (CC BY 4.0) license.
# DOI:10.24432/C56C76
#
#     Attribute Information:
#
# 1.sepal length in cm
# 2.sepal width in cm
# 3.petal length in cm
# 4.petal width in cm
# 5.class:
# -- Iris Setosa
# -- Iris Versicolour
# -- Iris Virginica
# </ul>
# </p>

# %% [markdown]
# # Exploratory data analysis

# %%
#Load the dataset
df=pd.read_csv("iris.csv",header=None)
df
# Out:
#        0    1    2    3               4
# 0    5.1  3.5  1.4  0.2     Iris-setosa
# 1    4.9  3.0  1.4  0.2     Iris-setosa
# 2    4.7  3.2  1.3  0.2     Iris-setosa
# 3    4.6  3.1  1.5  0.2     Iris-setosa
# 4    5.0  3.6  1.4  0.2     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 145  6.7  3.0  5.2  2.3  Iris-virginica
# 146  6.3  2.5  5.0  1.9  Iris-virginica
# 147  6.5  3.0  5.2  2.0  Iris-virginica
# 148  6.2  3.4  5.4  2.3  Iris-virginica
# 149  5.9  3.0  5.1  1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
# Column names
new_column = ['sepal length in cm', 'sepal width in cm ','petal length in cm', 'petal width in cm', 'class']
df.columns = new_column
df
# Out:
#      sepal length in cm  sepal width in cm   petal length in cm  \
# 0                   5.1                 3.5                 1.4
# 1                   4.9                 3.0                 1.4
# 2                   4.7                 3.2                 1.3
# 3                   4.6                 3.1                 1.5
# 4                   5.0                 3.6                 1.4
# ..                  ...                 ...                 ...
# 145                 6.7                 3.0                 5.2
# 146                 6.3                 2.5                 5.0
# 147                 6.5                 3.0                 5.2
# 148                 6.2                 3.4                 5.4
# 149                 5.9                 3.0                 5.1
#
#      petal width in cm           class
# 0                  0.2     Iris-setosa
# 1                  0.2     Iris-setosa
# 2                  0.2     Iris-setosa
# 3                  0.2     Iris-setosa
# 4                  0.2     Iris-setosa
# ..                 ...             ...
# 145                2.3  Iris-virginica
# 146                1.9  Iris-virginica
# 147                2.0  Iris-virginica
# 148                2.3  Iris-virginica
# 149                1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
df.head()
# Out:
#    sepal length in cm  sepal width in cm   petal length in cm  \
# 0                 5.1                 3.5                 1.4
# 1                 4.9                 3.0                 1.4
# 2                 4.7                 3.2                 1.3
# 3                 4.6                 3.1                 1.5
# 4                 5.0                 3.6                 1.4
#
#    petal width in cm        class
# 0                0.2  Iris-setosa
# 1                0.2  Iris-setosa
# 2                0.2  Iris-setosa
# 3                0.2  Iris-setosa
# 4                0.2  Iris-setosa

# %%
#Dimension of the dataframe
df.shape
# Out:
# (150, 5)

# %%
# All the columns
df.columns
# Out:
# Index(['sepal length in cm', 'sepal width in cm ', 'petal length in cm',
#        'petal width in cm', 'class'],
#       dtype='object')

# %%
#summary
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   sepal length in cm  150 non-null    float64
#  1   sepal width in cm   150 non-null    float64
#  2   petal length in cm  150 non-null    float64
#  3   petal width in cm   150 non-null    float64
#  4   class               150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
#Datatypes of each column
df.dtypes
# Out:
# sepal length in cm    float64
# sepal width in cm     float64
# petal length in cm    float64
# petal width in cm     float64
# class                  object
# dtype: object

# %%
#description statistics
df.describe()
# Out:
#        sepal length in cm  sepal width in cm   petal length in cm  \
# count          150.000000          150.000000          150.000000
# mean             5.843333            3.054000            3.758667
# std              0.828066            0.433594            1.764420
# min              4.300000            2.000000            1.000000
# 25%              5.100000            2.800000            1.600000
# 50%              5.800000            3.000000            4.350000
# 75%              6.400000            3.300000            5.100000
# max              7.900000            4.400000            6.900000
#
#        petal width in cm
# count         150.000000
# mean            1.198667
# std             0.763161
# min             0.100000
# 25%             0.300000
# 50%             1.300000
# 75%             1.800000
# max             2.500000

# %%
#unique values present in target column
df["class"].unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %% [markdown]
# ### Check proportion of each class

# %%
df['class'].value_counts()
# Out:
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: class, dtype: int64

# %% [markdown]
# Balanced dataset

# %% [markdown]
# ### Check for missing values

# %%
df.isnull()
df.isnull().sum()
# Out:
# sepal length in cm    0
# sepal width in cm     0
# petal length in cm    0
# petal width in cm     0
# class                 0
# dtype: int64

# %% [markdown]
# No missing value

# %% [markdown]
# ## Data Visualisation

# %%
sns.set_style('whitegrid')
sns.countplot(x='class',data=df)
# Out:
# <Axes: xlabel='class', ylabel='count'>

# %% [markdown]
# Balanced

# %% [markdown]
# ## Visualising different columns with respect to classes

# %%
plt.figure(figsize = (16,6))
sns.countplot(data=df, x="sepal length in cm", hue = "class", palette = 'inferno')
# Out:
# <Axes: xlabel='sepal length in cm', ylabel='count'>

# %% [markdown]
# Density of Sentosa is more on lower sepal length and density of virginica is more on higher sepal length.

# %%
plt.figure(figsize = (16,6))
sns.countplot(data=df, x="sepal width in cm ", hue = "class", palette = 'inferno')
# Out:
# <Axes: xlabel='sepal width in cm ', ylabel='count'>

# %% [markdown]
# Density of Sentosa is more on higher sepal width and density of versicolor is more on higher sepal width.

# %%
plt.figure(figsize = (16,6))
sns.countplot(data=df, x="petal length in cm", hue = "class", palette = 'inferno')
# Out:
# <Axes: xlabel='petal length in cm', ylabel='count'>

# %% [markdown]
# Density of Sentosa is more on lower petal length and density of virginica is more on higher petal length.

# %%
plt.figure(figsize = (16,6))
sns.countplot(data=df, x="petal width in cm", hue = "class", palette = 'inferno')
# Out:
# <Axes: xlabel='petal width in cm', ylabel='count'>

# %% [markdown]
# Density of Sentosa is more on lower petal width and density of virginica is more on higher petal width.

# %%
sns.set_style('whitegrid')
sns.FacetGrid(df, hue='class').map(plt.scatter,'sepal length in cm' ,'sepal width in cm ').add_legend()

# %% [markdown]
# Setosa can be classify easily.

# %%
sns.set_style('whitegrid')
sns.FacetGrid(df, hue='class').map(plt.scatter,'petal length in cm' ,'petal width in cm').add_legend()

# %% [markdown]
# ## Relationship of features with each other

# %%
# Visualise the whole dataset
sns.pairplot(df, hue='class')

# %% [markdown]
# Iris Setosa is easily distinguishable.
#
# Iris Setosa has  higher Sepal length.
#
# Iris Setosa has  lower Sepal width.
#
# Iris Setosa has  higher Petal length.
#
# Iris Setosa has  higher Petal width.

# %% [markdown]
# ### Histogram for four numerical features

# %%
df['sepal length in cm'].hist()
# Out:
# <Axes: >

# %%
# Plot graph for each column
df['sepal width in cm '].hist()
# Out:
# <Axes: >

# %%
# Plot graph for each column
df['petal length in cm'].hist()
# Out:
# <Axes: >

# %%
# Plot graph for each column
df['petal width in cm'].hist()
# Out:
# <Axes: >

# %% [markdown]
# ### Box Plot

# %%
# To Check the Outliers
plt.figure(figsize=[8,6])
sns.boxplot(x="class",y="sepal length in cm",data=df)
plt.title("Boxplot of Sepal length")
# Out:
# Text(0.5, 1.0, 'Boxplot of Sepal length')

# %% [markdown]
# No outliers

# %%
# To Check the Outliers
plt.figure(figsize=[8,6])
sns.boxplot(x="class",y="sepal width in cm ",data=df)
plt.title("Boxplot of Sepal width")
# Out:
# Text(0.5, 1.0, 'Boxplot of Sepal width')

# %% [markdown]
# Outlier is present

# %%
# To Check the Outliers
plt.figure(figsize=[8,6])
sns.boxplot(x="class",y="petal length in cm",data=df)
plt.title("Boxplot of Petal length")
# Out:
# Text(0.5, 1.0, 'Boxplot of Petal length')

# %% [markdown]
# No Outlier

# %%
# To Check the Outliers
plt.figure(figsize=[8,6])
sns.boxplot(x="class",y="petal width in cm",data=df)
plt.title("Boxplot of Petal width")
# Out:
# Text(0.5, 1.0, 'Boxplot of Petal width')

# %% [markdown]
# Outlier is present

# %% [markdown]
# ## Correlation metrics

# %%
df.corr()
# Out:
# C:\Users\shromana\AppData\Local\Temp\ipykernel_5656\1134722465.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                     sepal length in cm  sepal width in cm   \
# sepal length in cm            1.000000           -0.109369
# sepal width in cm            -0.109369            1.000000
# petal length in cm            0.871754           -0.420516
# petal width in cm             0.817954           -0.356544
#
#                     petal length in cm  petal width in cm
# sepal length in cm            0.871754           0.817954
# sepal width in cm            -0.420516          -0.356544
# petal length in cm            1.000000           0.962757
# petal width in cm             0.962757           1.000000

# %% [markdown]
# #### Correlation between the numerical variables

# %%
plt.figure(figsize=(7,4))
d=df.iloc[:,0:4]
sns.heatmap(d.corr(),annot=True)
plt.show()

# %% [markdown]
# There is negative correlation between sepal-length and sepal-width, petal length and sepal width, petal width and sepal width.
# petal length and petal width are highly correlated.

# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# ### Label Encoder

# %%
#Catergorical Feature to Integer

for column in df.columns:
    if df[column].dtype== np.number:
        continue
df[column] = LabelEncoder().fit_transform(df[column])
# Out:
# C:\Users\shromana\AppData\Local\Temp\ipykernel_5656\2875155213.py:4: DeprecationWarning: Converting `np.inexact` or `np.floating` to a dtype is deprecated. The current result is `float64` which is not strictly correct.
#   if df[column].dtype== np.number:

# %%
df['class'].unique()
# Out:
# array([0, 1, 2])

# %% [markdown]
# Three annotation for three labels.

# %%
df.dtypes
# Out:
# sepal length in cm    float64
# sepal width in cm     float64
# petal length in cm    float64
# petal width in cm     float64
# class                   int32
# dtype: object

# %%
df.head()
# Out:
#    sepal length in cm  sepal width in cm   petal length in cm  \
# 0                 5.1                 3.5                 1.4
# 1                 4.9                 3.0                 1.4
# 2                 4.7                 3.2                 1.3
# 3                 4.6                 3.1                 1.5
# 4                 5.0                 3.6                 1.4
#
#    petal width in cm  class
# 0                0.2      0
# 1                0.2      0
# 2                0.2      0
# 3                0.2      0
# 4                0.2      0

# %% [markdown]
# ## Splitting of Dataset

# %%
X = df.drop(['class'], axis=1)
y = df['class']

# %% [markdown]
# Features and target are separated

# %%
X
# Out:
#      sepal length in cm  sepal width in cm   petal length in cm  \
# 0                   5.1                 3.5                 1.4
# 1                   4.9                 3.0                 1.4
# 2                   4.7                 3.2                 1.3
# 3                   4.6                 3.1                 1.5
# 4                   5.0                 3.6                 1.4
# ..                  ...                 ...                 ...
# 145                 6.7                 3.0                 5.2
# 146                 6.3                 2.5                 5.0
# 147                 6.5                 3.0                 5.2
# 148                 6.2                 3.4                 5.4
# 149                 5.9                 3.0                 5.1
#
#      petal width in cm
# 0                  0.2
# 1                  0.2
# 2                  0.2
# 3                  0.2
# 4                  0.2
# ..                 ...
# 145                2.3
# 146                1.9
# 147                2.0
# 148                2.3
# 149                1.8
#
# [150 rows x 4 columns]

# %%
y
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 145    2
# 146    2
# 147    2
# 148    2
# 149    2
# Name: class, Length: 150, dtype: int32

# %%
#Dimension of the dataset
print(X.shape)
print(y.shape)
# Out:
# (150, 4)
# (150,)

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size = 0.3)

# %%
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (105, 4)
# (105,)
# (45, 4)
# (45,)

# %% [markdown]
# 70 percent training, 30 percent testing

# %% [markdown]
# ### Normalize the numerical variables

# %%
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %% [markdown]
# # Model

# %%
# To check the best value of K
k_range = list(range(1,15))
acc = []
for i in k_range:
    knn = KNeighborsClassifier(n_neighbors=i).fit(X_train , y_train)
    y_pred = knn.predict(X_test)
    acc.append(metrics.accuracy_score(y_test, y_pred))
print(acc)
plt.plot(k_range,acc)
plt.xlabel('Vale of K')
plt.ylabel('Accuracy Score')
plt.title('K vs Score')
plt.show()
# Out:
# [0.9333333333333333, 0.9333333333333333, 0.9555555555555556, 0.9333333333333333, 0.9555555555555556, 0.9555555555555556, 0.9555555555555556, 0.9777777777777777, 0.9777777777777777, 0.9555555555555556, 0.9555555555555556, 0.9555555555555556, 0.9777777777777777, 0.9777777777777777]

# %% [markdown]
# Accuracy of the model is 97% for K=8

# %% [markdown]
# ### Accuracy of the model

# %%
knn = KNeighborsClassifier(n_neighbors=8).fit(X_train , y_train)
y_pred = knn.predict(X_test)
knn_acc=accuracy_score(y_test, y_pred)
print(knn_acc)
# Out:
# 0.9777777777777777

# %% [markdown]
# Accuracy of the model is 97.78%

# %% [markdown]
# ### Classification Report

# %%
print(metrics.classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        17
#            1       0.94      1.00      0.97        16
#            2       1.00      0.92      0.96        12
#
#     accuracy                           0.98        45
#    macro avg       0.98      0.97      0.98        45
# weighted avg       0.98      0.98      0.98        45

# %%
print(metrics.confusion_matrix(y_test,y_pred))
# Out:
# [[17  0  0]
#  [ 0 16  0]
#  [ 0  1 11]]

# %% [markdown]
# ### Prediction

# %%
y_pred = knn.predict(X_test)
print(y_pred)
# Out:
# [0 1 2 0 0 1 2 2 1 1 1 0 1 0 0 0 1 2 2 1 2 1 0 1 0 2 0 2 2 0 0 1 1 1 1 2 1
#  1 2 0 0 1 0 0 0]

# %% [markdown]
# 0:Iris-setosa
# 1:Iris-versicolor
# 2:Iris-virginica

# %% [markdown]
# #### Prediction on new data

# %%
new_data = pd.DataFrame({
   'sepal length in cm' : [5.1],
    'sepal width in cm ': [3.5],
    'petal length cm': [1.4],
    'petal width cm': [0.2]
})

scaler = StandardScaler()
scaled_new_data = scaler.fit_transform(new_data)

predicted_species = knn.predict(scaled_new_data)

print(f"The predicted species is {predicted_species}")
# Out:
# The predicted species is [1]

# %%
#### Saving the model

# %%
with open('KNN_model.pkl','wb') as file:
    pickle.dump( knn,file)
